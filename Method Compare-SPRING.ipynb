# %%
from kan import *
import pytz
import time
import datetime
import torch.optim as optim
from data_process import data_process_without_norm
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import copy
import pandas as pd

df = data_process_without_norm()
df = df.drop("entsoe",axis=1)
loc_tz = pytz.timezone('Europe/Zurich')
split_date_train_ = loc_tz.localize(datetime.datetime(2016,1,1,0,0,0,0))
split_date_train = loc_tz.localize(datetime.datetime(2016,3,1,0,0,0,0))
split_date_test = loc_tz.localize(datetime.datetime(2016,3,15,0,0,0,0))

df_train_ = df.loc[(split_date_train_ < df.index)]
df_train = df_train_.loc[df_train_.index <= split_date_train].copy()
_temp_df = df.loc[split_date_test > df.index]
df_test = _temp_df.loc[_temp_df.index > split_date_train].copy()

# Input standardization
scaler_input = StandardScaler()
# scaler_input = MinMaxScalerr()
_temp_scaled_input_data = scaler_input.fit_transform(df_train.iloc[:,1:])
x_train_input = _temp_scaled_input_data

#Output standardization
scaler_output = StandardScaler()
# scaler_input = MinMaxScaler()
_temp_scaled_output_data = scaler_output.fit_transform(np.array(df_train.iloc[:,0]).reshape(-1,1))
x_train_label = _temp_scaled_output_data

#Test set standardization
x_test_input = scaler_input.transform(df_test.iloc[:,1:])
x_test_label = scaler_output.transform(np.array(df_test.iloc[:,0]).reshape(-1,1))

_temp_test_input = np.hstack((x_test_input[:,:8],x_test_input[:,-3:-1]))
_temp_test_label = x_test_label
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

_temp_train_input = np.hstack((x_train_input[:, :8], x_train_input[:, -3:-1]))
_temp_train_label = x_train_label

# 将数据转换为 PyTorch 张量
train_input_tensor = torch.tensor(_temp_train_input.astype(np.float32))
train_label_tensor = torch.tensor(_temp_train_label.astype(np.float32))

test_input_tensor = torch.tensor(_temp_test_input.astype(np.float32))
test_label_tensor = torch.tensor(_temp_test_label.astype(np.float32))
# 定义 k 折交叉验证
k = 5  # 例如，5折交叉验证
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
# CNN 模型
class CNN(nn.Module):
    def __init__(self, num_inputs, num_outputs, conv_out_channels=16, time_step=24):
        super(CNN, self).__init__()
        self.conv = nn.Conv1d(in_channels=num_inputs, out_channels=conv_out_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.fc = nn.Linear(conv_out_channels * time_step, num_outputs)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # 调整输入形状为 (batch_size, num_inputs, time_step)
        x = self.conv(x)
        x = self.relu(x)
        x = x.view(x.size(0), -1)  # 展平
        x = self.fc(x)
        return x

# LSTM 模型
class LSTM(nn.Module):
    def __init__(self, num_inputs, num_outputs, lstm_hidden_units=16):
        super(LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=num_inputs, hidden_size=lstm_hidden_units, batch_first=True)
        self.fc = nn.Linear(lstm_hidden_units, num_outputs)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :]  # 取最后一个时间步的输出
        x = self.fc(x)
        return x

# CNNLSTM 模型
class CNNLSTM(nn.Module):
    def __init__(self, num_inputs, num_outputs, conv_out_channels=16, lstm_hidden_units=16, time_step=24):
        super(CNNLSTM, self).__init__()
        self.conv = nn.Conv1d(in_channels=num_inputs, out_channels=conv_out_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.lstm = nn.LSTM(input_size=conv_out_channels, hidden_size=lstm_hidden_units, batch_first=True)
        self.fc = nn.Linear(lstm_hidden_units, num_outputs)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # 调整输入形状为 (batch_size, num_inputs, time_step)
        x = self.conv(x)
        x = self.relu(x)
        x = x.permute(0, 2, 1)  # 调整回 LSTM 所需的输入形状 (batch_size, time_step, conv_out_channels)
        x, _ = self.lstm(x)
        x = x[:, -1, :]  # 取最后一个时间步的输出
        x = self.fc(x)
        return x

# Transformer 模型
class Transformer(nn.Module):
    def __init__(self, num_inputs, num_outputs, d_model=16, num_heads=2, num_layers=2):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(num_inputs, d_model)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=d_model, nhead=num_heads),
            num_layers=num_layers
        )
        self.fc = nn.Linear(d_model, num_outputs)

    def forward(self, x):
        x = self.embedding(x)
        x = self.transformer(x)
        x = self.fc(x)
        return x

# FCN1 模型
class FCN1(nn.Module):
    def __init__(self, num_inputs, num_outputs, hidden_units=16):
        super(FCN1, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(num_inputs, hidden_units),
            nn.ReLU(),
            nn.Linear(hidden_units, num_outputs)
        )

    def forward(self, x):
        return self.net(x)

# FCN2 模型
class FCN2(nn.Module):
    def __init__(self, num_inputs, num_outputs, hidden_units1=32, hidden_units2=16):
        super(FCN2, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(num_inputs, hidden_units1),
            nn.ReLU(),
            nn.Linear(hidden_units1, hidden_units2),
            nn.ReLU(),
            nn.Linear(hidden_units2, num_outputs)
        )

    def forward(self, x):
        return self.net(x)

# 定义损失函数
loss_func = nn.MSELoss()

# 超参数范围
learning_rates = [0.01, 0.005, 0.001]
batch_sizes = [128, 64, 32]

# K折交叉验证
k = 3
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
# 超参数范围
learning_rates = [0.01, 0.005, 0.001]
batch_sizes = [128, 64, 32]
num_epochs_list = [50, 100]
hidden_units_list = [16, 32]

def create_time_series_data(data, time_step):
    num_samples = data.shape[0]
    num_features = data.shape[1]
    time_series_data = []

    for i in range(num_samples - time_step + 1):
        time_series_data.append(data[i:i + time_step].clone().detach().numpy())

    return torch.tensor(np.array(time_series_data))

def train_and_evaluate_model(model_class, num_inputs, num_outputs, train_input_tensor, train_label_tensor, time_step=24):
    results = []
    for lr in learning_rates:
        for batch_size in batch_sizes:
            for num_epochs in num_epochs_list:
                for hidden_units in hidden_units_list:
                    fold_results = []
                    for fold, (train_index, val_index) in enumerate(kf.split(train_input_tensor)):
                        # 创建模型实例
                        if model_class in [CNN, CNNLSTM]:
                            model = model_class(num_inputs, num_outputs, hidden_units, time_step)
                        else:
                            model = model_class(num_inputs, num_outputs, hidden_units)

                        optimizer = optim.Adam(model.parameters(), lr=lr)

                        # 分割数据
                        train_input_fold = train_input_tensor[train_index]
                        train_label_fold = train_label_tensor[train_index]
                        val_input_fold = train_input_tensor[val_index]
                        val_label_fold = train_label_tensor[val_index]

                        # 如果模型是CNN或LSTM，转换数据为时间序列格式
                        if issubclass(model_class, (CNN, LSTM, CNNLSTM)):
                            train_input_fold = create_time_series_data(train_input_fold, time_step)
                            train_label_fold = train_label_fold[time_step - 1:]  # 对齐标签
                            val_input_fold = create_time_series_data(val_input_fold, time_step)
                            val_label_fold = val_label_fold[time_step - 1:]  # 对齐标签

                        # 创建数据加载器
                        train_loader = torch.utils.data.DataLoader(
                            dataset=torch.utils.data.TensorDataset(train_input_fold.clone().detach(), train_label_fold.clone().detach()),
                            batch_size=batch_size,
                            shuffle=True
                        )
                        val_loader = torch.utils.data.DataLoader(
                            dataset=torch.utils.data.TensorDataset(val_input_fold.clone().detach(), val_label_fold.clone().detach()),
                            batch_size=batch_size,
                            shuffle=False
                        )

                        # 训练模型
                        start_time = time.time()
                        for epoch in range(num_epochs):
                            model.train()
                            for step, (x, y) in enumerate(train_loader):
                                output = model(x)
                                loss = loss_func(output, y)
                                optimizer.zero_grad()
                                loss.backward()
                                optimizer.step()

                        # 验证模型
                        model.eval()
                        val_loss = 0
                        with torch.no_grad():
                            for x, y in val_loader:
                                output = model(x)
                                loss = loss_func(output, y)
                                val_loss += loss.item()
                        val_loss /= len(val_loader)
                        fold_results.append(val_loss)
                        end_time = time.time()
                        print(f"Fold {fold + 1}, LR: {lr}, Batch Size: {batch_size}, Epochs: {num_epochs}, Hidden Units: {hidden_units}, Validation Loss: {val_loss:.4f}, Time: {end_time - start_time:.2f} seconds")

                    # 计算当前超参数组合在所有折上的平均损失
                    avg_val_loss = np.mean(fold_results)
                    results.append({
                        'learning_rate': lr,
                        'batch_size': batch_size,
                        'num_epochs': num_epochs,
                        'hidden_units': hidden_units,
                        'avg_val_loss': avg_val_loss
                    })

    # 转换结果为DataFrame以便分析
    results_df = pd.DataFrame(results)

    # 找到最佳配置
    best_config = results_df.loc[results_df['avg_val_loss'].idxmin()]

    print(f"\nBest Configuration for {model_class.__name__}: {best_config}")
    return results_df
      
# 评估每个模型
cnn_results = train_and_evaluate_model(CNN, num_inputs=10, num_outputs=1, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor)
lstm_results = train_and_evaluate_model(LSTM, num_inputs=10, num_outputs=1, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor)
cnn_lstm_results = train_and_evaluate_model(CNNLSTM, num_inputs=10, num_outputs=1, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor)
transformer_results = train_and_evaluate_model(Transformer, num_inputs=10, num_outputs=1, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor)
fcn1_results = train_and_evaluate_model(FCN1, num_inputs=10, num_outputs=1, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor)
fcn2_results = train_and_evaluate_model(FCN2, num_inputs=10, num_outputs=1, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor)
# Out:
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5897, Time: 1.23 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.9388, Time: 6.42 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6818, Time: 7.44 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5116, Time: 6.77 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.8190, Time: 5.79 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5931, Time: 6.20 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6236, Time: 15.26 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8376, Time: 14.31 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7775, Time: 15.02 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5325, Time: 14.33 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 1.1007, Time: 13.79 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7832, Time: 14.97 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4930, Time: 13.28 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6344, Time: 13.47 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6236, Time: 12.08 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5800, Time: 11.69 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7036, Time: 12.42 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6161, Time: 12.71 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6331, Time: 27.53 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7111, Time: 26.71 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8222, Time: 26.94 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5969, Time: 28.17 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7305, Time: 25.95 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7675, Time: 24.94 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4703, Time: 26.18 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7800, Time: 26.50 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7262, Time: 27.03 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4427, Time: 23.02 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6515, Time: 24.58 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7957, Time: 23.78 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6055, Time: 53.65 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7091, Time: 44.21 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7248, Time: 53.76 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5377, Time: 46.63 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6612, Time: 47.16 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6203, Time: 50.23 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5647, Time: 7.80 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8423, Time: 7.66 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6573, Time: 7.95 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5661, Time: 7.10 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7365, Time: 6.94 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6324, Time: 6.74 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5839, Time: 15.48 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8638, Time: 16.58 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6178, Time: 16.80 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5842, Time: 15.24 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.8314, Time: 15.64 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6659, Time: 14.62 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6726, Time: 13.07 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 1.0384, Time: 13.17 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8174, Time: 10.45 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4853, Time: 10.72 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.8514, Time: 11.25 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.8316, Time: 12.52 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5896, Time: 28.46 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8840, Time: 27.73 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8659, Time: 21.85 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5354, Time: 20.02 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.8205, Time: 26.10 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7450, Time: 27.38 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5040, Time: 27.31 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7748, Time: 27.67 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7164, Time: 25.90 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5586, Time: 21.72 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7001, Time: 23.24 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7406, Time: 26.32 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5249, Time: 52.64 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7861, Time: 46.60 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7080, Time: 51.12 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5644, Time: 44.71 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7644, Time: 44.73 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6898, Time: 42.71 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6264, Time: 9.19 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7852, Time: 7.40 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7543, Time: 9.68 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6464, Time: 7.00 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7853, Time: 7.50 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6357, Time: 6.60 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5899, Time: 14.88 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7697, Time: 15.44 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8429, Time: 15.60 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6200, Time: 13.58 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.9588, Time: 15.03 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6974, Time: 15.22 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5959, Time: 13.35 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.9075, Time: 11.77 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8986, Time: 12.90 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6443, Time: 12.45 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.8984, Time: 12.75 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.8167, Time: 12.14 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6004, Time: 25.73 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8750, Time: 26.96 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7536, Time: 26.67 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5837, Time: 27.06 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.8593, Time: 24.29 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7263, Time: 24.42 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5512, Time: 26.24 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8566, Time: 25.79 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7223, Time: 27.03 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5738, Time: 24.28 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7323, Time: 23.57 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6569, Time: 23.62 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5308, Time: 52.12 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7012, Time: 55.48 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7820, Time: 52.41 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6207, Time: 46.22 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.9031, Time: 48.09 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7736, Time: 48.58 seconds
#
# Best Configuration for SimpleCNN: learning_rate     0.010000
# batch_size       64.000000
# num_epochs       50.000000
# hidden_units     16.000000
# avg_val_loss      0.583664
# Name: 4, dtype: float64
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3726, Time: 12.23 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6396, Time: 15.47 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4402, Time: 11.93 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4488, Time: 14.56 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6892, Time: 19.92 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4112, Time: 12.32 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2908, Time: 29.06 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5857, Time: 27.93 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.4003, Time: 37.89 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.4058, Time: 29.34 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5422, Time: 27.75 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.4885, Time: 29.55 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2431, Time: 20.81 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3245, Time: 20.47 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4169, Time: 16.34 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3318, Time: 21.91 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6329, Time: 19.02 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4933, Time: 16.04 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2583, Time: 46.78 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6186, Time: 33.56 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6064, Time: 28.21 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3019, Time: 45.18 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.4576, Time: 31.04 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5305, Time: 32.65 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2242, Time: 18.22 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5802, Time: 12.74 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4281, Time: 11.95 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2532, Time: 19.82 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3707, Time: 22.15 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4433, Time: 22.01 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2802, Time: 28.07 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2697, Time: 28.38 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3996, Time: 30.67 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2327, Time: 39.47 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.4919, Time: 36.76 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3341, Time: 39.24 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4560, Time: 11.15 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7472, Time: 12.11 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5762, Time: 12.31 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4697, Time: 9.82 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.8777, Time: 10.37 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7294, Time: 11.80 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.4451, Time: 26.22 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7567, Time: 22.15 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5674, Time: 18.29 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5547, Time: 22.67 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.8712, Time: 22.07 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5795, Time: 21.03 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4076, Time: 16.09 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5955, Time: 13.49 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6083, Time: 17.07 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4695, Time: 18.51 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.8775, Time: 17.83 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6581, Time: 17.02 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3828, Time: 35.59 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6746, Time: 31.75 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6513, Time: 31.61 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.4709, Time: 31.00 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7115, Time: 34.11 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6345, Time: 33.72 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3832, Time: 18.00 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5168, Time: 15.02 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4519, Time: 16.19 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4152, Time: 20.64 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4747, Time: 20.88 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4961, Time: 21.86 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3593, Time: 26.52 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5639, Time: 26.74 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5136, Time: 34.35 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3393, Time: 40.94 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.4948, Time: 39.64 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.4495, Time: 40.77 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6814, Time: 11.59 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6101, Time: 14.21 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6769, Time: 14.16 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5952, Time: 12.71 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.9133, Time: 16.11 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7965, Time: 16.01 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6105, Time: 21.89 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8337, Time: 22.45 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8623, Time: 26.86 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7174, Time: 24.28 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.8108, Time: 26.20 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.9329, Time: 30.52 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4426, Time: 21.64 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8582, Time: 19.31 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7835, Time: 20.24 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5822, Time: 15.03 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.9953, Time: 16.13 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7560, Time: 17.37 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3774, Time: 32.41 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.9761, Time: 34.99 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6566, Time: 33.42 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7280, Time: 31.87 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 1.0736, Time: 38.06 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7181, Time: 28.46 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4647, Time: 16.07 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7728, Time: 13.75 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.9185, Time: 17.83 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6239, Time: 23.99 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7912, Time: 18.82 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7620, Time: 22.70 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5039, Time: 33.77 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 1.1573, Time: 30.90 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5689, Time: 31.88 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6648, Time: 37.11 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 1.2202, Time: 40.16 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.7563, Time: 45.02 seconds
#
# Best Configuration for SimpleLSTM: learning_rate      0.010000
# batch_size        32.000000
# num_epochs       100.000000
# hidden_units      16.000000
# avg_val_loss       0.316523
# Name: 10, dtype: float64
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3216, Time: 22.34 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8082, Time: 20.51 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4329, Time: 24.80 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3527, Time: 18.63 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4206, Time: 22.34 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4354, Time: 19.73 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3500, Time: 40.50 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8719, Time: 42.71 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.4874, Time: 45.28 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2846, Time: 46.01 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3915, Time: 40.97 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3851, Time: 57.18 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2217, Time: 42.80 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4760, Time: 32.36 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4727, Time: 39.82 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2813, Time: 34.23 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4461, Time: 32.00 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3546, Time: 34.56 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2952, Time: 71.15 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5332, Time: 73.53 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.4242, Time: 66.74 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2571, Time: 72.96 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3540, Time: 76.67 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2689, Time: 75.93 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2219, Time: 51.16 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3432, Time: 50.00 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3540, Time: 61.69 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2730, Time: 44.29 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2432, Time: 55.99 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3850, Time: 49.06 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2332, Time: 87.38 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3764, Time: 93.33 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3857, Time: 97.83 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2211, Time: 94.13 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3312, Time: 86.79 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2922, Time: 94.17 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3848, Time: 27.38 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8109, Time: 21.57 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4706, Time: 18.18 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4285, Time: 22.03 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6738, Time: 23.02 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4705, Time: 18.92 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3370, Time: 45.69 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7912, Time: 46.46 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5676, Time: 42.95 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3203, Time: 43.60 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6656, Time: 42.92 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5180, Time: 38.43 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3313, Time: 32.98 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6285, Time: 30.49 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5433, Time: 30.71 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3025, Time: 27.87 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6196, Time: 32.15 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5160, Time: 32.15 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3834, Time: 64.50 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5803, Time: 63.13 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5525, Time: 67.02 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2754, Time: 61.75 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5102, Time: 58.13 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5136, Time: 63.40 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2834, Time: 42.20 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4446, Time: 47.82 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5140, Time: 44.55 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2417, Time: 37.37 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4714, Time: 40.69 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4864, Time: 40.11 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3381, Time: 91.12 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3323, Time: 71.97 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.4049, Time: 90.67 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2479, Time: 79.58 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3533, Time: 83.54 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3194, Time: 84.20 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6135, Time: 20.53 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8740, Time: 21.04 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.6137, Time: 18.85 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6795, Time: 20.77 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 1.1719, Time: 22.23 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6463, Time: 19.48 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.7017, Time: 44.30 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 1.0666, Time: 41.54 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.8580, Time: 39.44 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5728, Time: 37.81 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 1.0498, Time: 33.72 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6739, Time: 33.73 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4981, Time: 25.15 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8753, Time: 31.74 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7328, Time: 29.83 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4893, Time: 32.55 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6927, Time: 29.32 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6552, Time: 28.87 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.4922, Time: 70.49 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 1.0090, Time: 64.57 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 1.2184, Time: 65.02 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5057, Time: 66.63 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 1.2365, Time: 62.96 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.6965, Time: 72.32 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4669, Time: 44.86 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.8243, Time: 46.74 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.7255, Time: 34.13 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.5283, Time: 46.81 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 1.0229, Time: 40.48 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.6216, Time: 47.26 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.5632, Time: 86.39 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 1.2022, Time: 94.78 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.6973, Time: 75.63 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5363, Time: 88.37 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.9433, Time: 73.39 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.5015, Time: 82.20 seconds
#
# Best Configuration for CNNLSTM: learning_rate      0.010000
# batch_size        32.000000
# num_epochs       100.000000
# hidden_units      32.000000
# avg_val_loss       0.281476
# Name: 11, dtype: float64
# C:\Users\23124862r\AppData\Local\anaconda3\envs\kan\lib\site-packages\torch\nn\modules\transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1796, Time: 25.21 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2163, Time: 26.78 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2202, Time: 22.27 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3579, Time: 23.25 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3534, Time: 26.25 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.7669, Time: 30.31 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1372, Time: 43.83 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1096, Time: 44.13 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1110, Time: 53.10 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0983, Time: 55.34 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3055, Time: 52.30 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2963, Time: 56.24 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1888, Time: 40.48 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1206, Time: 43.57 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1772, Time: 44.92 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.9389, Time: 47.26 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1375, Time: 46.93 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2583, Time: 40.40 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.0943, Time: 73.63 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1064, Time: 78.96 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1014, Time: 79.05 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.8290, Time: 105.79 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1701, Time: 84.09 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2115, Time: 98.31 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2425, Time: 74.92 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1744, Time: 73.66 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2126, Time: 78.30 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 1.0073, Time: 73.37 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4194, Time: 84.74 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.8951, Time: 81.29 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2824, Time: 152.61 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1217, Time: 147.44 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1355, Time: 145.23 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.8851, Time: 154.18 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.9555, Time: 159.70 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.9755, Time: 156.61 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1539, Time: 24.86 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1479, Time: 25.03 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1501, Time: 25.54 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2000, Time: 26.48 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1141, Time: 31.28 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1123, Time: 29.94 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.0813, Time: 50.42 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.0805, Time: 52.77 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1126, Time: 45.20 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0753, Time: 57.59 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0809, Time: 49.48 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0921, Time: 50.37 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1386, Time: 37.99 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.0933, Time: 38.06 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1940, Time: 36.90 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1294, Time: 39.67 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1076, Time: 38.71 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.0941, Time: 35.38 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1105, Time: 71.83 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.0959, Time: 71.94 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1073, Time: 72.02 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1093, Time: 79.19 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0775, Time: 86.29 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1027, Time: 82.00 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1693, Time: 64.98 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1204, Time: 62.43 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1574, Time: 59.20 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1219, Time: 66.65 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1336, Time: 73.23 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1458, Time: 74.50 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1004, Time: 133.06 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1144, Time: 115.73 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.0878, Time: 104.48 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1044, Time: 111.49 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0781, Time: 112.21 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0862, Time: 108.44 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1434, Time: 15.89 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1325, Time: 16.25 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2725, Time: 16.62 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1350, Time: 18.04 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1039, Time: 17.95 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1621, Time: 17.97 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1253, Time: 32.23 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1075, Time: 31.16 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1314, Time: 31.36 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0857, Time: 34.65 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0908, Time: 36.50 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0804, Time: 35.76 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1652, Time: 26.58 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1189, Time: 27.45 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1865, Time: 27.55 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1030, Time: 27.89 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.0987, Time: 28.21 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1512, Time: 28.37 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.0948, Time: 54.88 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.0827, Time: 57.38 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1256, Time: 57.68 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0890, Time: 59.51 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0687, Time: 60.10 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1172, Time: 59.63 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1339, Time: 52.75 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1086, Time: 51.07 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1443, Time: 51.97 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1204, Time: 56.97 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.0784, Time: 55.31 seconds
# ...
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.5489, Time: 1.12 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4271, Time: 1.13 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3505, Time: 1.12 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4817, Time: 1.18 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3734, Time: 2.35 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2890, Time: 2.41 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.4043, Time: 2.33 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3452, Time: 2.34 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2590, Time: 2.32 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3725, Time: 2.41 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4159, Time: 1.50 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2937, Time: 1.53 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4118, Time: 1.52 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3718, Time: 1.57 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2698, Time: 1.56 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.4136, Time: 1.54 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3517, Time: 3.02 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2609, Time: 3.09 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3672, Time: 3.14 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2975, Time: 3.03 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2623, Time: 3.18 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3311, Time: 3.15 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3916, Time: 2.51 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3436, Time: 2.78 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.4774, Time: 2.69 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3231, Time: 2.55 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2519, Time: 2.49 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3618, Time: 2.58 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3221, Time: 5.46 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2307, Time: 5.42 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3507, Time: 5.40 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2921, Time: 5.24 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2291, Time: 5.01 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.3135, Time: 5.01 seconds
#
# Best Configuration for SimpleFCN1: learning_rate      0.010000
# batch_size        32.000000
# num_epochs       100.000000
# hidden_units      32.000000
# avg_val_loss       0.179947
# Name: 11, dtype: float64
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2069, Time: 1.31 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1862, Time: 1.29 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1992, Time: 1.30 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1627, Time: 1.36 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1317, Time: 1.33 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1931, Time: 1.33 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1691, Time: 2.59 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1640, Time: 2.53 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2226, Time: 2.65 seconds
# Fold 1, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1297, Time: 2.66 seconds
# Fold 2, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1286, Time: 2.66 seconds
# Fold 3, LR: 0.01, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1496, Time: 2.66 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2107, Time: 1.78 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1762, Time: 1.89 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2002, Time: 1.81 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1351, Time: 1.86 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1464, Time: 1.80 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1581, Time: 1.84 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1518, Time: 3.61 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1652, Time: 3.58 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1476, Time: 3.76 seconds
# Fold 1, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1089, Time: 3.65 seconds
# Fold 2, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1080, Time: 3.49 seconds
# Fold 3, LR: 0.01, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1291, Time: 3.59 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1731, Time: 2.89 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1590, Time: 2.80 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2010, Time: 2.87 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1519, Time: 2.98 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1267, Time: 2.89 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1456, Time: 2.97 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1105, Time: 5.76 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1310, Time: 6.02 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1696, Time: 6.16 seconds
# Fold 1, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0932, Time: 6.08 seconds
# Fold 2, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0960, Time: 6.19 seconds
# Fold 3, LR: 0.01, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1201, Time: 6.31 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2264, Time: 1.30 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1883, Time: 1.33 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2597, Time: 1.32 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1994, Time: 1.31 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1666, Time: 1.41 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2415, Time: 1.35 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1961, Time: 2.61 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1832, Time: 2.51 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2320, Time: 2.56 seconds
# Fold 1, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1557, Time: 2.57 seconds
# Fold 2, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1285, Time: 2.59 seconds
# Fold 3, LR: 0.005, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1811, Time: 2.55 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1911, Time: 1.68 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1637, Time: 1.79 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2236, Time: 1.83 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1889, Time: 1.77 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1551, Time: 1.86 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2037, Time: 1.78 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1494, Time: 3.62 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1561, Time: 3.81 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1980, Time: 3.88 seconds
# Fold 1, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1555, Time: 3.94 seconds
# Fold 2, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1067, Time: 3.92 seconds
# Fold 3, LR: 0.005, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1679, Time: 3.82 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1655, Time: 3.07 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1623, Time: 3.40 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.1780, Time: 3.17 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1313, Time: 3.05 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1488, Time: 3.20 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1513, Time: 3.06 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1520, Time: 6.10 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1359, Time: 10.24 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1679, Time: 6.17 seconds
# Fold 1, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1178, Time: 6.11 seconds
# Fold 2, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.0991, Time: 6.17 seconds
# Fold 3, LR: 0.005, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1368, Time: 6.34 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3350, Time: 1.36 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3037, Time: 1.33 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3858, Time: 1.29 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3123, Time: 1.42 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2443, Time: 1.30 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 50, Hidden Units: 32, Validation Loss: 0.3642, Time: 1.31 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2544, Time: 2.67 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2150, Time: 2.57 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 16, Validation Loss: 0.3088, Time: 2.48 seconds
# Fold 1, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2615, Time: 2.66 seconds
# Fold 2, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1819, Time: 2.70 seconds
# Fold 3, LR: 0.001, Batch Size: 128, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2621, Time: 2.70 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3230, Time: 1.79 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2284, Time: 1.71 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3301, Time: 1.88 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2463, Time: 1.81 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.1996, Time: 1.79 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2838, Time: 1.86 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2659, Time: 3.53 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1730, Time: 3.67 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2330, Time: 3.54 seconds
# Fold 1, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2154, Time: 3.52 seconds
# Fold 2, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1701, Time: 3.49 seconds
# Fold 3, LR: 0.001, Batch Size: 64, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2699, Time: 3.55 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2589, Time: 2.85 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.2032, Time: 2.82 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 16, Validation Loss: 0.3062, Time: 2.93 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2342, Time: 3.00 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2042, Time: 3.06 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 50, Hidden Units: 32, Validation Loss: 0.2774, Time: 3.01 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2113, Time: 6.03 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.1967, Time: 6.00 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 16, Validation Loss: 0.2808, Time: 6.09 seconds
# Fold 1, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1905, Time: 6.37 seconds
# Fold 2, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.1524, Time: 6.25 seconds
# Fold 3, LR: 0.001, Batch Size: 32, Epochs: 100, Hidden Units: 32, Validation Loss: 0.2265, Time: 6.04 seconds
#
# Best Configuration for SimpleFCN2: learning_rate      0.010000
# batch_size        32.000000
# num_epochs       100.000000
# hidden_units      32.000000
# avg_val_loss       0.103107
# Name: 11, dtype: float64

# %%
results_df = pd.DataFrame(cnn_results)
results_df.to_csv('./parameters_configuration/cnn_BaseConfig-SPRING.csv') 
results_df = pd.DataFrame(lstm_results)
results_df.to_csv('./parameters_configuration/lstm_BaseConfig-SPRING.csv') 
results_df = pd.DataFrame(cnn_lstm_results)
results_df.to_csv('./parameters_configuration/cnn_lstm_BaseConfig-SPRING.csv') 
results_df = pd.DataFrame(transformer_results)
results_df.to_csv('./parameters_configuration/transformer_BaseConfig-SPRING.csv') 
results_df = pd.DataFrame(fcn1_results)
results_df.to_csv('./parameters_configuration/fcn1_BaseConfig-SPRING.csv') 
results_df = pd.DataFrame(fcn2_results)
results_df.to_csv('./parameters_configuration/fcn2_BaseConfig-SPRING.csv')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

results_df_cnn = pd.read_csv('./parameters_configuration/cnn_BaseConfig-SPRING.csv',index_col=0)
results_df_lstm = pd.read_csv('./parameters_configuration/lstm_BaseConfig-SPRING.csv',index_col=0)
results_df_cnn_lstm = pd.read_csv('./parameters_configuration/cnn_lstm_BaseConfig-SPRING.csv',index_col=0)
results_df_transformer = pd.read_csv('./parameters_configuration/transformer_BaseConfig-SPRING.csv',index_col=0)
results_df_fcn1 = pd.read_csv('./parameters_configuration/fcn1_BaseConfig-SPRING.csv',index_col=0)
results_df_fcn2 = pd.read_csv('./parameters_configuration/fcn2_BaseConfig-SPRING.csv',index_col=0)
def train_and_test_model(model_class, learning_rate, batch_size, num_epochs, hidden_units, train_input_tensor, train_label_tensor, test_input_tensor, test_label_tensor, scaler_output, num_inputs=10, num_outputs=1, time_step=24):
    results = []

    # 如果模型是CNN或LSTM，转换数据为时间序列格式
    if issubclass(model_class, (CNN, LSTM, CNNLSTM)):
        train_input_tensor = create_time_series_data(train_input_tensor, time_step)
        train_label_tensor = train_label_tensor[time_step - 1:]  # 对齐标签
        test_input_tensor = create_time_series_data(test_input_tensor, time_step)
        test_label_tensor = test_label_tensor[time_step - 1:]  # 对齐标签

    # 创建数据加载器
    train_loader = torch.utils.data.DataLoader(
        dataset=torch.utils.data.TensorDataset(train_input_tensor.clone().detach(), train_label_tensor.clone().detach()),
        batch_size=int(batch_size),
        shuffle=True
    )

    # 初始化模型、损失函数和优化器
    model = model_class(num_inputs, num_outputs, hidden_units)
    loss_func = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # 训练模型
    start_time = time.time()
    for epoch in range(num_epochs):
        model.train()
        for step, (x, y) in enumerate(train_loader):
            output = model(x)
            loss = loss_func(output, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    # 验证模型
    model.eval()
    with torch.no_grad():
        output = model(test_input_tensor.clone().detach())
        output_inverse = scaler_output.inverse_transform(output.numpy())
        test_label_inverse = scaler_output.inverse_transform(test_label_tensor.numpy())

        # 计算评估指标
        rmse = np.sqrt(mean_squared_error(test_label_inverse, output_inverse))
        mae = mean_absolute_error(test_label_inverse, output_inverse)
        mape = np.mean(np.abs((test_label_inverse - output_inverse) / test_label_inverse)) * 100

        test_loss = loss_func(output, test_label_tensor.clone().detach()).item()

    # print(f"Test Loss: {test_loss:.4f}")

    results.append({
        'RMSE': rmse,
        'MAE': mae,
        'MAPE': mape
    })

    return results

# %%
# 找到每个模型的最佳配置
def get_best_config(results_df):
    best_config = results_df.loc[results_df['avg_val_loss'].idxmin(), ['learning_rate', 'batch_size', 'num_epochs', 'hidden_units']]
    return {
        'learning_rate': best_config['learning_rate'],
        'batch_size': int(best_config['batch_size']),
        'num_epochs': int(best_config['num_epochs']),
        'hidden_units': int(best_config['hidden_units'])
    }

# 获取每个模型的最佳配置
best_config_cnn = get_best_config(results_df_cnn)
best_config_lstm = get_best_config(results_df_lstm)
best_config_cnn_lstm = get_best_config(results_df_cnn_lstm)
best_config_transformer = get_best_config(results_df_transformer)
best_config_fcn1 = get_best_config(results_df_fcn1)
best_config_fcn2 = get_best_config(results_df_fcn2)

# 假设 train_input_tensor, train_label_tensor, test_input_tensor, test_label_tensor 已经定义

# 训练和测试每个模型，并打印结果
cnn_test_results = train_and_test_model(CNN, **best_config_cnn, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor, test_input_tensor=test_input_tensor, test_label_tensor=test_label_tensor, scaler_output=scaler_output)
print("CNN Test Results:", cnn_test_results)

lstm_test_results = train_and_test_model(LSTM, **best_config_lstm, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor, test_input_tensor=test_input_tensor, test_label_tensor=test_label_tensor, scaler_output=scaler_output)
print("LSTM Test Results:", lstm_test_results)

cnn_lstm_test_results = train_and_test_model(CNNLSTM, **best_config_cnn_lstm, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor, test_input_tensor=test_input_tensor, test_label_tensor=test_label_tensor, scaler_output=scaler_output)
print("CNN-LSTM Test Results:", cnn_lstm_test_results)

transformer_test_results = train_and_test_model(Transformer, **best_config_transformer, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor, test_input_tensor=test_input_tensor, test_label_tensor=test_label_tensor, scaler_output=scaler_output)
print("Transformer Test Results:", transformer_test_results)

fcn1_test_results = train_and_test_model(FCN1, **best_config_fcn1, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor, test_input_tensor=test_input_tensor, test_label_tensor=test_label_tensor, scaler_output=scaler_output)
print("FCN1 Test Results:", fcn1_test_results)

fcn2_test_results = train_and_test_model(FCN2, **best_config_fcn2, train_input_tensor=train_input_tensor, train_label_tensor=train_label_tensor, test_input_tensor=test_input_tensor, test_label_tensor=test_label_tensor, scaler_output=scaler_output)
print("FCN2 Test Results:", fcn2_test_results)
# Out:
# CNN Test Results: [{'RMSE': 363.12497, 'MAE': 284.53516, 'MAPE': 3.8278382271528244}]
# LSTM Test Results: [{'RMSE': 374.975, 'MAE': 295.3712, 'MAPE': 3.956039622426033}]
# CNN-LSTM Test Results: [{'RMSE': 382.98364, 'MAE': 304.5893, 'MAPE': 4.069294407963753}]
# C:\Users\23124862r\AppData\Local\anaconda3\envs\kan\lib\site-packages\torch\nn\modules\transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Transformer Test Results: [{'RMSE': 395.73175, 'MAE': 282.6444, 'MAPE': 3.799699991941452}]
# FCN1 Test Results: [{'RMSE': 379.38968, 'MAE': 307.85696, 'MAPE': 4.097015410661697}]
# FCN2 Test Results: [{'RMSE': 367.3222, 'MAE': 288.25598, 'MAPE': 3.80210317671299}]

# %%
result = dict()
result["cnn"] = cnn_test_results
result["lstm"] = lstm_test_results
result["cnn_lstm"] = cnn_lstm_test_results
result["transformer"] = transformer_test_results
result["fcn1"] = fcn1_test_results
result["fcn2"] = fcn2_test_results

# %%
result
# Out:
# {'cnn': [{'RMSE': 363.12497, 'MAE': 284.53516, 'MAPE': 3.8278382271528244}],
#  'lstm': [{'RMSE': 374.975, 'MAE': 295.3712, 'MAPE': 3.956039622426033}],
#  'cnn_lstm': [{'RMSE': 382.98364, 'MAE': 304.5893, 'MAPE': 4.069294407963753}],
#  'transformer': [{'RMSE': 395.73175,
#    'MAE': 282.6444,
#    'MAPE': 3.799699991941452}],
#  'fcn1': [{'RMSE': 379.38968, 'MAE': 307.85696, 'MAPE': 4.097015410661697}],
#  'fcn2': [{'RMSE': 367.3222, 'MAE': 288.25598, 'MAPE': 3.80210317671299}]}
